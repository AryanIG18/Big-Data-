# %% [markdown]
# # Pandas Built-In Data Visualization

# %%
# Importing the libraries
# matplotlib allows to make high quality data visualization 
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/gdrive')
root_path = 'gdrive/mydrive/'
# Out:
# Mounted at /content/gdrive

# %%
#Importing the file
df1= pd.read_csv('gdrive/My Drive/D1.unknown',index_col=0)
df2 = pd.read_csv('gdrive/My Drive/df2.csv.unknown')

# %%
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %% [markdown]
# # HISTOGRAM

# %%
#Making Histogram
import matplotlib.pyplot as plt
plt.style.use('ggplot')
df1['A'].hist()
# Out:
# <Axes: >

# %%
plt.style.use('bmh')
df1['A'].hist()
# Out:
# <Axes: >

# %%
plt.style.use('dark_background')
df1['A'].hist()
# Out:
# <Axes: >

# %%
plt.style.use('bmh')
df1['A'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # **PLOT TYPE**

# %% [markdown]
# # AREA

# %%
df2.plot.area(alpha=0.4)
# Out:
# <Axes: >

# %%
df2.plot.area()
# Out:
# <Axes: >

# %% [markdown]
# # BARPLOTS

# %%
#This will show the First 5 rows in dataset
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
# Making Barplot
df2.plot.bar()
# Out:
# <Axes: >

# %%
#Maing stacked barplot
df2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %% [markdown]
# # HISTOGRAM

# %%
#Making Histogam
# Bins refer to the number of intervals or groups that a continuous range of data is divided into for analysis, visualization etc.
df1['A'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# **bold text**# TEXTPLOT

# %%
#importing packages
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#loading dataset
data = sns.load_dataset("iris")

# draw lineplot
sns.lineplot(x="sepal_length",y="sepal_width", data=data)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# # SCATTER PLOT

# %%
df1.plot.scatter(x='A',y='B')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*200)
# Out:
# /usr/local/lib/python3.9/dist-packages/matplotlib/collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# # IRIS

# %%
Iris= pd.read_csv('gdrive/My Drive/Iris.csv')

# %%
Iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
plt.style.use('ggplot')
Iris['SepalLengthCm'].hist()
# Out:
# <Axes: >

# %%
Iris['SepalLengthCm'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>
